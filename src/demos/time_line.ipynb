# %% [markdown]
# # Time Line

# %% [markdown]
# ### Importing Dataset and Libraries

# %%
import pandas as pd
import altair as alt
alt.data_transformers.disable_max_rows()
import numpy as np

# %%
anime = pd.read_csv("../../data/preprocessed_anime.csv")

# %%
anime.head(2)
# Out:
#    anime_id                             Name  Score  \
# 0         1                     Cowboy Bebop   8.78
# 1         5  Cowboy Bebop: Tengoku no Tobira   8.39
#
#                                             Genres            English name  \
# 0  Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1            Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
#
#     Japanese name                                          sypnopsis   Type  \
# 0       カウボーイビバップ  In the year 2071, humanity has colonized sever...     TV
# 1  カウボーイビバップ 天国の扉  other day, another bounty—such is the life of ...  Movie
#
#   Episodes                        Aired  ... Ranked Popularity  Members  \
# 0       26  Apr 3, 1998 to Apr 24, 1999  ...   28.0         39  1251960
# 1        1                  Sep 1, 2001  ...  159.0        518   273145
#
#   Favorites Watching Completed On-Hold  Dropped  start_date    end_date
# 0     61971   105808    718161   71513    26678  1998-04-03  1999-04-24
# 1      1174     4143    208333    1935      770  2001-09-01  2001-09-01
#
# [2 rows x 27 columns]
