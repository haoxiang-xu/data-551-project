# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/anime-filtered.csv')

# %%
def get_top_3_animes(df):
    top_3 = df.nlargest(3, "Score")[["Name", "Score"]]
    return [{"title": row["Name"], "score": f"{row['Score']:.2f}"} for _, row in top_3.iterrows()]

def get_average_score(df):
    return round(df["Score"].mean(), 2)

# %%
get_top_3_animes(df)
# Out:
# [{'title': 'Fullmetal Alchemist: Brotherhood', 'score': '9.19'},
#  {'title': 'Shingeki no Kyojin: The Final Season', 'score': '9.17'},
#  {'title': 'Steins;Gate', 'score': '9.11'}]

# %%
get_average_score(df)
# Out:
# np.float64(6.51)
